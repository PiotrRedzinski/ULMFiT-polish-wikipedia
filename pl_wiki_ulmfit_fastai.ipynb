# %% [markdown]
# # Introduction

# %% [markdown]
# This is a notebook that show a few tricks that allow to create language model with fastai, ULMFiT and Colab free GPU for polish wikipedia.

# %% [markdown]
# Although fastai works fine on PC with newest python, it would take aproximetely 60 days to create model with CPU only. In Colab python3.6 there are some bugs, and below I show how to make it working with Colab GPU within 20 hours of GPU.

# %% [markdown]
# First of all sometimes "Terminate" button is disabled in Colab Jupiter Notebook. Then restart is possible with:

# %% [markdown]
# Please see original notebooks from fastai team:
# https://github.com/fastai/course-nlp/blob/master/nn-turkish.ipynb

# %%
# !kill -9 -1

# %% [markdown]
# # Data preparation

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# At first running autoreload should be started, but after first data.py code change Restart runtime is required and then reload section should be skipped.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.text import *

# %%
torch.cuda.get_device_name(0) #check GPU
# Out:
# 'Tesla P100-PCIE-16GB'

# %%
data_path = Config.data_path()
lang = 'pl'
name = f'{lang}wiki'
path = data_path/name
path.mkdir(exist_ok=True, parents=True)

mdl_path = path/'models'
mdl_path.mkdir(exist_ok=True)
lm_fns = [mdl_path/f'{lang}_wt', mdl_path/f'{lang}_wt_vocab']

# %%
cd /content/gdrive/My\ Drive/
# Out:
# /content/gdrive/My Drive

# %%
os.getcwd()
# Out:
# '/content/gdrive/My Drive'

# %% [markdown]
# Here I had some problem wih importing nlputils, so I copied it, adding one more function extract_only which can be helpful. (.. to be imporoved)

# %%
from fastai.basics import *
import re


def get_wiki(path,lang):
    name = f'{lang}wiki'
    if (path/name).exists():
        print(f"{path/name} already exists; not downloading")
        return
    
    xml_fn = f"{lang}wiki-latest-pages-articles.xml"
    zip_fn = f"{xml_fn}.bz2"
    
    if not (path/xml_fn).exists():
        print("downloading...")
        download_url(f'https://dumps.wikimedia.org/{name}/latest/{zip_fn}', path/zip_fn)
        print("unzipping...")
        bunzip(path/zip_fn)
    
    with working_directory(path):
        if not (path/'wikiextractor').exists(): os.system('git clone https://github.com/attardi/wikiextractor.git')
        print("extracting...")
        os.system("python wikiextractor/WikiExtractor.py --processes 4 --no_templates " +
            f"--min_text_length 1800 --filter_disambig_pages --log_file log -b 100G -q {xml_fn}")
    shutil.move(str(path/'text/AA/wiki_00'), str(path/name))
    shutil.rmtree(path/'text')


def extract_only(path,lang):
    name = f'{lang}wiki'
    xml_fn = f"{lang}wiki-latest-pages-articles.xml"
    with working_directory(path):
        if not (path/'wikiextractor').exists(): os.system('git clone https://github.com/attardi/wikiextractor.git')
        print("extracting...")
        os.system("python wikiextractor/WikiExtractor.py --processes 4 --no_templates " +
            f"--min_text_length 1800 --filter_disambig_pages --log_file log -b 100G -q {xml_fn}")
    shutil.move(str(path/'text/AA/wiki_00'), str(path/name))
    shutil.rmtree(path/'text')


def split_wiki(path,lang):
    dest = path/'docs'
    name = f'{lang}wiki'
    if dest.exists():
        print(f"{dest} already exists; not splitting")
        return dest

    dest.mkdir(exist_ok=True, parents=True)
    title_re = re.compile(rf'<doc id="\d+" url="https://{lang}.wikipedia.org/wiki\?curid=\d+" title="([^"]+)">')
    lines = (path/name).open()
    f=None

    for i,l in enumerate(lines):
        if i%100000 == 0: print(i)
        if l.startswith('<doc id="'):
            try:
                title = title_re.findall(l)[0].replace('/','_').replace(':','_')
            except:
                title = 'title{}'.format(i)
            if len(title)>150: continue
            if f: f.close()
            f = (dest/f'{title}.txt').open('w')
        else: f.write(l)
    f.close()
    return dest

# %%
get_wiki(path,lang)
# !head -n4 {path}/{name}
# Out:
# downloading...
# unzipping...
# extracting...
# <doc id="2" url="https://pl.wikipedia.org/wiki?curid=2" title="AWK">
# AWK
#
# AWK – interpretowany język programowania, którego główną funkcją jest wyszukiwanie i przetwarzanie wzorców w plikach lub strumieniach danych. Jest także nazwą programu początkowo dostępnego dla systemów operacyjnych będących pochodnymi UNIX-a, obecnie także na inne platformy.

# %%
# !ls /root/.fastai/data/plwiki
# Out:
# docs   models				 plwiki-latest-pages-articles.xml.bz2
# doc_s  plwiki				 wikiextractor
# log    plwiki-latest-pages-articles.xml

# %%
dest = split_wiki(path,lang)
# Out:
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000
# 1700000
# 1800000
# 1900000
# 2000000
# 2100000
# 2200000
# 2300000
# 2400000
# 2500000
# 2600000
# 2700000
# 2800000
# 2900000
# 3000000
# 3100000
# 3200000
# 3300000
# 3400000
# 3500000
# 3600000
# 3700000
# 3800000
# 3900000
# 4000000
# 4100000
# 4200000
# 4300000
# 4400000
# 4500000
# 4600000
# 4700000
# 4800000
# 4900000
# 5000000
# 5100000
# 5200000
# 5300000
# 5400000
# 5500000
# 5600000
# 5700000
# 5800000
# 5900000
# 6000000
# 6100000

# %%
# !ls /root/.fastai/data/plwiki/docs/Zygmunt\ U*
# Out:
# '/root/.fastai/data/plwiki/docs/Zygmunt Ułanowicz.txt'
# '/root/.fastai/data/plwiki/docs/Zygmunt Ulm.txt'
# '/root/.fastai/data/plwiki/docs/Zygmunt Unrug.txt'
# '/root/.fastai/data/plwiki/docs/Zygmunt Urbanyj.txt'

# %%
# !cat '/root/.fastai/data/plwiki/docs/Zygmunt Unrug.txt'
# Out:
# Zygmunt Unrug
#
# Zygmunt Unrug (ur. 1676 w Międzychodzie, zm. 1 maja 1732) – polski szlachcic z rodu Unrugów, dyplomata, protestant (brat czeski). Absolwent szkoły w Lesznie, następnie Uniwersytetu we Frankfurcie, prześladowany z powodów religijnych.
#
# Urodził się w 1676. Był synem Krzysztofa Unruga (1624-1689) herbu własnego, właściciela Międzychodu i Kargowej, starosty gnieźnieńskiego i wałeckiego oraz Bogumiły Jaskóleckiej herbu Zaremba. Po ojcu odziedziczył Poniec, Kawcze, Szelejewo i Zduny. Ożenił się z Beatą Szarlotą Luizą Gorzeńską herbu Nałęcz. Mieli dwóch synów: Chryzostoma Zygmunta i Krzysztofa Zygmunta (1728-1768), późniejszego generała armii koronnej.
#
# Był pułkownikiem armii koronnej, a od 1698 starostą gnieźnieńskim. W 1705 potwierdził "pacta conventa" Stanisława Leszczyńskiego. Przyczynił się do detronizacji Augusta II Sasa, ujawniając jego tajne listy. W 1708 król Stanisław Leszczyński wysłał go do Berlina by wybadał nastawienie Fryderyka I do Polski i chęć ewentualnej mediacji pruskiej, między konfederacją sandomierską a zwolennikami Stanisława. Ponieważ Unrug ani nie obiecywał ustępstw terytorialnych, ani nie uznawał w imieniu RP królewskiego tytułu Fryderyka (Królestwo Prus powstało w 1701 a Rzeczpospolita go nie uznawała), spotkał się z chłodnym przyjęciem. Fryderyk nie miał zamiaru złamać sojuszy ze Szwedami z 1703 i 1707 . Ostatecznie Leszczyńskiemu pomagał w mediacji ze Szwedami poseł francuski w Polsce Jean Louis d’Usson de Bonnac.
#
# W 1715 został przez Trybunał Główny Koronny w Piotrkowie skazany na śmierć za wywód teologiczny uznany za bluźnierczy. Orzeczono następującą karę: Chodziło o znajdujące się w jego "silva rerum" zdanie zacytowane z dzieł pewnego katolickiego księdza (żyjącego w XVII w.), wyrwane z kontekstu a przede wszystkim celowo przeinaczone przez oskarżyciela Andrzeja Potockiego (tryb pytający przedstawiono sędziom jako twierdzący, co w istotny sposób zmieniło sens owej myśli). Obawiając się kaźni zmuszony był uciec z kraju.
#
# W jego obronie stanęła szlachta (zarówno dysydencka jak i część katolickiej) oraz niektórzy z katolickich biskupów, w tym nuncjusz apostolski abp Vincenzo Santini w imieniu papieża Innocentego XI, a także Uniwersytet Paryski. Na Sejmie 1726 przy okazji rozpatrywania innych skarg przeciw Trybunałowi, uchwalono jego "Korekturę", ponowiono ustawy z lat 1627 i 1638 zabraniające Trybunałowi wydawać wyroki bez oparcia ich na obowiązującym prawie (zwane "vim legis sapiunt", łac. "uchodzące za mające moc prawa"), wyrok skazujący anulowano, jedynie sprawę jego majątku (skonfiskowanego i w części przyznanego oskarżycielowi) odłożono na przyszły Sejm (który został zerwany). Ostatecznie wyrokiem z 9 marca 1741 Trybunał oddalił pretensje oskarżycieli do tej części majątku, którą jego rodzina zdołała odzyskać.
#
#
#
#
# </doc>

# %%
# !cp /content/gdrive/My\ Drive/language_model/data/plwiki/plwiki_old /root/.fastai/data/plwiki/

# %%
# !ls -l /root/.fastai/data/plwiki/doc_s
# Out:
# total 6052
# -rw-r--r-- 1 root root 3698372 Jan 18 18:35  pl_databunch
# drwxr-xr-x 2 root root    4096 Jan 18 18:34  tmp
# -rw-r--r-- 1 root root    2401 Jan 18 18:12 'Zybert II Dobry.txt'
# -rw-r--r-- 1 root root    4413 Jan 18 18:12  Zybułtowo.txt
# -rw-r--r-- 1 root root   10160 Jan 18 18:12 'Zyfia gęsiogłowa.txt'
# -rw-r--r-- 1 root root    2076 Jan 18 18:12  Zyfiowate.txt
# -rw-r--r-- 1 root root    2149 Jan 18 18:12 'Zygaena fausta.txt'
# -rw-r--r-- 1 root root    4940 Jan 18 18:12 'Zygfryd Berezecki.txt'
# -rw-r--r-- 1 root root    4735 Jan 18 18:12 'Zygfryd Czempisz.txt'
# -rw-r--r-- 1 root root    2075 Jan 18 18:12 'Zygfryd Goldfinger.txt'
# -rw-r--r-- 1 root root    2473 Jan 18 18:12 'Zygfryd Gölis.txt'
# -rw-r--r-- 1 root root    3060 Jan 18 18:12 'Zygfryd II z Eppsteinu.txt'
# -rw-r--r-- 1 root root    2470 Jan 18 18:12 'Zygfryd I (palatyn reński).txt'
# -rw-r--r-- 1 root root    2448 Jan 18 18:12 'Zygfryd Kuchta.txt'
# -rw-r--r-- 1 root root    1962 Jan 18 18:12 'Zygfryd Kuliński.txt'
# -rw-r--r-- 1 root root    2046 Jan 18 18:12 'Zygfryd (opera).txt'
# -rw-r--r-- 1 root root    3067 Jan 18 18:12 'Zygfryd Rymaszewski.txt'
# -rw-r--r-- 1 root root    2855 Jan 18 18:12 'Zygfryd Sznek.txt'
# -rw-r--r-- 1 root root   18835 Jan 18 18:12 'Zygfryd Szołtysik.txt'
# -rw-r--r-- 1 root root    2391 Jan 18 18:12 'Zygfryd von Boock.txt'
# -rw-r--r-- 1 root root    2315 Jan 18 18:12 'Zygfryd Wolniak.txt'
# -rw-r--r-- 1 root root    2800 Jan 18 18:12 'Zygfryd z Westerburga.txt'
# -rw-r--r-- 1 root root    2083 Jan 18 18:12 'Zyghard von Schwarzburg.txt'
# -rw-r--r-- 1 root root    2018 Jan 18 18:12 'Zygmunt Albert.txt'
# -rw-r--r-- 1 root root    3419 Jan 18 18:12 'Zygmunt Anczok.txt'
# -rw-r--r-- 1 root root    3222 Jan 18 18:12 'Zygmunt Andrzej Heinrich.txt'
# -rw-r--r-- 1 root root    2281 Jan 18 18:12 'Zygmunt Andrzej Wielopolski.txt'
# -rw-r--r-- 1 root root    2430 Jan 18 18:12 'Zygmunt August Wrześniowski.txt'
# -rw-r--r-- 1 root root   18297 Jan 18 18:12 'Zygmunt Augustyński.txt'
# -rw-r--r-- 1 root root    2086 Jan 18 18:12 'Zygmunt Balicki (inżynier).txt'
# -rw-r--r-- 1 root root    1954 Jan 18 18:12 'Zygmunt Balicki.txt'
# -rw-r--r-- 1 root root    3799 Jan 18 18:12 'Zygmunt Bartkiewicz.txt'
# -rw-r--r-- 1 root root    3248 Jan 18 18:12 'Zygmunt Batowski.txt'
# -rw-r--r-- 1 root root   18451 Jan 18 18:12 'Zygmunt Bauman.txt'
# -rw-r--r-- 1 root root    2550 Jan 18 18:12 'Zygmunt Berdychowski.txt'
# -rw-r--r-- 1 root root   19848 Jan 18 18:12 'Zygmunt Berling.txt'
# -rw-r--r-- 1 root root    2730 Jan 18 18:12 'Zygmunt Bezeg.txt'
# -rw-r--r-- 1 root root    4558 Jan 18 18:12 'Zygmunt Bezucha.txt'
# -rw-r--r-- 1 root root    2041 Jan 18 18:12 'Zygmunt Białogłowski.txt'
# -rw-r--r-- 1 root root    3431 Jan 18 18:12 'Zygmunt Bieszczanin.txt'
# -rw-r--r-- 1 root root    5205 Jan 18 18:12 'Zygmunt Błażejewicz.txt'
# -rw-r--r-- 1 root root    3972 Jan 18 18:12 'Zygmunt Blumski.txt'
# -rw-r--r-- 1 root root    4786 Jan 18 18:12 'Zygmunt Bobrowski (1898–1973).txt'
# -rw-r--r-- 1 root root    2661 Jan 18 18:12 'Zygmunt Bohdanowski.txt'
# -rw-r--r-- 1 root root    9905 Jan 18 18:12 'Zygmunt Bohusz-Szyszko.txt'
# -rw-r--r-- 1 root root    3608 Jan 18 18:12 'Zygmunt Boras.txt'
# -rw-r--r-- 1 root root    2999 Jan 18 18:12 'Zygmunt Borawski.txt'
# -rw-r--r-- 1 root root    4502 Jan 18 18:12 'Zygmunt Bratkowski.txt'
# -rw-r--r-- 1 root root    6139 Jan 18 18:12 'Zygmunt Brockhusen.txt'
# -rw-r--r-- 1 root root    1910 Jan 18 18:12 'Zygmunt Brodowski.txt'
# -rw-r--r-- 1 root root    1966 Jan 18 18:12 'Zygmunt Broniarek.txt'
# -rw-r--r-- 1 root root    6691 Jan 18 18:12 'Zygmunt Broniewski.txt'
# -rw-r--r-- 1 root root    2439 Jan 18 18:12 'Zygmunt Brykalski.txt'
# -rw-r--r-- 1 root root    4198 Jan 18 18:12 'Zygmunt Brynk.txt'
# -rw-r--r-- 1 root root    2126 Jan 18 18:12 'Zygmunt Bugajski.txt'
# -rw-r--r-- 1 root root    1923 Jan 18 18:12 'Zygmunt Bujnicki.txt'
# -rw-r--r-- 1 root root    6323 Jan 18 18:12 'Zygmunt Bukowiński.txt'
# -rw-r--r-- 1 root root    5268 Jan 18 18:12 'Zygmunt Bychowski.txt'
# -rw-r--r-- 1 root root    2508 Jan 18 18:12 'Zygmunt Celichowski.txt'
# -rw-r--r-- 1 root root    2700 Jan 18 18:12 'Zygmunt Cetnerowski.txt'
# -rw-r--r-- 1 root root    2725 Jan 18 18:12 'Zygmunt Chajzer.txt'
# -rw-r--r-- 1 root root    7027 Jan 18 18:12 'Zygmunt Chamiec.txt'
# -rw-r--r-- 1 root root    2622 Jan 18 18:12 'Zygmunt Chełmicki.txt'
# -rw-r--r-- 1 root root    2825 Jan 18 18:12 'Zygmunt Chlebowski.txt'
# -rw-r--r-- 1 root root    2561 Jan 18 18:12 'Zygmunt Chmieleński.txt'
# -rw-r--r-- 1 root root    2159 Jan 18 18:12 'Zygmunt Chmielewski (aktor).txt'
# -rw-r--r-- 1 root root    3399 Jan 18 18:12 'Zygmunt Chodorowski.txt'
# -rw-r--r-- 1 root root    6610 Jan 18 18:12 'Zygmunt Choromański.txt'
# -rw-r--r-- 1 root root    2452 Jan 18 18:12 'Zygmunt Chychła.txt'
# -rw-r--r-- 1 root root    2021 Jan 18 18:12 'Zygmunt Ciechanowski.txt'
# -rw-r--r-- 1 root root    9977 Jan 18 18:12 'Zygmunt Cšadek.txt'
# -rw-r--r-- 1 root root    1928 Jan 18 18:12 'Zygmunt Cwenarski.txt'
# -rw-r--r-- 1 root root    3715 Jan 18 18:12 'Zygmunt Cybichowski.txt'
# -rw-r--r-- 1 root root    2093 Jan 18 18:12 'Zygmunt Cybulski.txt'
# -rw-r--r-- 1 root root    2365 Jan 18 18:12 'Zygmunt Cytowicz.txt'
# -rw-r--r-- 1 root root    2768 Jan 18 18:12 'Zygmunt Czarzasty.txt'
# -rw-r--r-- 1 root root    2640 Jan 18 18:12 'Zygmunt Czerny.txt'
# -rw-r--r-- 1 root root    4475 Jan 18 18:12 'Zygmunt Czerwiński.txt'
# -rw-r--r-- 1 root root    2894 Jan 18 18:12 'Zygmunt Czubiński.txt'
# -rw-r--r-- 1 root root    3009 Jan 18 18:12 'Zygmunt Czyżowski (kasztelan).txt'
# -rw-r--r-- 1 root root    4043 Jan 18 18:12 'Zygmunt Czyż.txt'
# -rw-r--r-- 1 root root    1970 Jan 18 18:12 'Zygmunt Dąbkowski.txt'
# -rw-r--r-- 1 root root    3806 Jan 18 18:12 'Zygmunt Dadlez.txt'
# -rw-r--r-- 1 root root    2831 Jan 18 18:12 'Zygmunt Dąmbski.txt'
# -rw-r--r-- 1 root root    2871 Jan 18 18:12 'Zygmunt Denhoff (zm. 1655).txt'
# -rw-r--r-- 1 root root    3948 Jan 18 18:12 'Zygmunt Deyczakowski.txt'
# -rw-r--r-- 1 root root    4294 Jan 18 18:12 'Zygmunt Dobrowolski.txt'
# -rw-r--r-- 1 root root    2035 Jan 18 18:12 'Zygmunt Dobrzycki.txt'
# -rw-r--r-- 1 root root    2564 Jan 18 18:12 'Zygmunt Domagalski.txt'
# -rw-r--r-- 1 root root    4536 Jan 18 18:12 'Zygmunt Drzymała.txt'
# -rw-r--r-- 1 root root    4909 Jan 18 18:12 'Zygmunt Durski.txt'
# -rw-r--r-- 1 root root    3465 Jan 18 18:12 'Zygmunt Duszyński.txt'
# -rw-r--r-- 1 root root    2521 Jan 18 18:12 'Zygmunt Dziarmaga-Działyński.txt'
# -rw-r--r-- 1 root root    4093 Jan 18 18:12 'Zygmunt Dzwonkowski.txt'
# -rw-r--r-- 1 root root    2746 Jan 18 18:12 'Zygmunt Ellenberg.txt'
# -rw-r--r-- 1 root root    3084 Jan 18 18:12 'Zygmunt Ertel.txt'
# -rw-r--r-- 1 root root    1945 Jan 18 18:12 'Zygmunt Eysmontt.txt'
# -rw-r--r-- 1 root root    8359 Jan 18 18:12 'Zygmunt Felczak.txt'
# -rw-r--r-- 1 root root    4178 Jan 18 18:12 'Zygmunt Filip Manowarda.txt'
# -rw-r--r-- 1 root root    2210 Jan 18 18:12 'Zygmunt Filipowicz.txt'
# -rw-r--r-- 1 root root    3384 Jan 18 18:12 'Zygmunt Frankiewicz.txt'
# -rw-r--r-- 1 root root    2115 Jan 18 18:12 'Zygmunt Frykowski.txt'
# -rw-r--r-- 1 root root    4638 Jan 18 18:12 'Zygmunt Gabert.txt'
# -rw-r--r-- 1 root root    3530 Jan 18 18:12 'Zygmunt Gardecki.txt'
# -rw-r--r-- 1 root root    4563 Jan 18 18:12 'Zygmunt Gaworski.txt'
# -rw-r--r-- 1 root root    3630 Jan 18 18:12 'Zygmunt Gilewicz.txt'
# -rw-r--r-- 1 root root    4854 Jan 18 18:12 'Zygmunt Gloger.txt'
# -rw-r--r-- 1 root root    3588 Jan 18 18:12 'Zygmunt Głowacki.txt'
# -rw-r--r-- 1 root root    4598 Jan 18 18:12 'Zygmunt Gogolewski.txt'
# -rw-r--r-- 1 root root    3707 Jan 18 18:12 'Zygmunt Goławski (1912–1944).txt'
# -rw-r--r-- 1 root root    4009 Jan 18 18:12 'Zygmunt Goławski.txt'
# -rw-r--r-- 1 root root    2745 Jan 18 18:12 'Zygmunt Golonka.txt'
# -rw-r--r-- 1 root root    6696 Jan 18 18:12 'Zygmunt Gonzaga Myszkowski.txt'
# -rw-r--r-- 1 root root    5205 Jan 18 18:12 'Zygmunt Gorazdowski.txt'
# -rw-r--r-- 1 root root    3292 Jan 18 18:12 'Zygmunt Gordon.txt'
# -rw-r--r-- 1 root root    3403 Jan 18 18:12 'Zygmunt Gorgolewski.txt'
# -rw-r--r-- 1 root root    2120 Jan 18 18:12 'Zygmunt Górski (leśnik).txt'
# -rw-r--r-- 1 root root    5118 Jan 18 18:12 'Zygmunt Górski.txt'
# -rw-r--r-- 1 root root    2017 Jan 18 18:12 'Zygmunt Grabowiecki.txt'
# -rw-r--r-- 1 root root    2332 Jan 18 18:12 'Zygmunt Grabowski (pułkownik).txt'
# -rw-r--r-- 1 root root    3191 Jan 18 18:12 'Zygmunt Gromnicki.txt'
# -rw-r--r-- 1 root root    3012 Jan 18 18:12 'Zygmunt Grzebieniak.txt'
# -rw-r--r-- 1 root root    2386 Jan 18 18:12 'Zygmunt Guldenstern.txt'
# -rw-r--r-- 1 root root    3659 Jan 18 18:12 'Zygmunt Habsburg.txt'
# -rw-r--r-- 1 root root    3367 Jan 18 18:12 'Zygmunt Haduch-Suski.txt'
# -rw-r--r-- 1 root root    2169 Jan 18 18:12 'Zygmunt Haupt.txt'
# -rw-r--r-- 1 root root    7076 Jan 18 18:12 'Zygmunt Hempel.txt'
# -rw-r--r-- 1 root root    2960 Jan 18 18:12 'Zygmunt Hendel.txt'
# -rw-r--r-- 1 root root    3239 Jan 18 18:12 'Zygmunt Hertz.txt'
# -rw-r--r-- 1 root root    7749 Jan 18 18:12 'Zygmunt Heryng.txt'
# -rw-r--r-- 1 root root    2779 Jan 18 18:12 'Zygmunt Hofmokl-Ostrowski.txt'
# -rw-r--r-- 1 root root    3731 Jan 18 18:12 'Zygmunt Holcer.txt'
# -rw-r--r-- 1 root root    2727 Jan 18 18:12 'Zygmunt Holewiński.txt'
# -rw-r--r-- 1 root root    3329 Jan 18 18:12 'Zygmunt Horyd.txt'
# -rw-r--r-- 1 root root    6193 Jan 18 18:12 'Zygmunt Hübner.txt'
# -rw-r--r-- 1 root root    4235 Jan 18 18:12 'Zygmunt Huszcza.txt'
# -rw-r--r-- 1 root root    3338 Jan 18 18:12 'Zygmunt Hyży.txt'
# -rw-r--r-- 1 root root   12461 Jan 18 18:12 'Zygmunt II August.txt'
# -rw-r--r-- 1 root root   16693 Jan 18 18:12 'Zygmunt III Waza.txt'
# -rw-r--r-- 1 root root   17774 Jan 18 18:12 'Zygmunt I Stary.txt'
# -rw-r--r-- 1 root root    4700 Jan 18 18:12 'Zygmunt I Święty.txt'
# -rw-r--r-- 1 root root    4033 Jan 18 18:12 'Zygmunt Izdebski.txt'
# -rw-r--r-- 1 root root    3051 Jan 18 18:12 'Zygmunt Jaeschke.txt'
# -rw-r--r-- 1 root root    2246 Jan 18 18:12 'Zygmunt Janiszewski.txt'
# -rw-r--r-- 1 root root    4583 Jan 18 18:12 'Zygmunt Jan Manowarda.txt'
# -rw-r--r-- 1 root root    2489 Jan 18 18:12 'Zygmunt Jeleń.txt'
# -rw-r--r-- 1 root root    4549 Jan 18 18:12 'Zygmunt Jerzy Kuczyński.txt'
# -rw-r--r-- 1 root root    1987 Jan 18 18:12 'Zygmunt Jezierski.txt'
# -rw-r--r-- 1 root root    3352 Jan 18 18:12 'Zygmunt Jordan.txt'
# -rw-r--r-- 1 root root    2017 Jan 18 18:12 'Zygmunt Jórski.txt'
# -rw-r--r-- 1 root root    5360 Jan 18 18:12 'Zygmunt Kaczkowski.txt'
# -rw-r--r-- 1 root root    5664 Jan 18 18:12 'Zygmunt Kaczyński (duchowny).txt'
# -rw-r--r-- 1 root root    3661 Jan 18 18:12 'Zygmunt Kadłubowski.txt'
# -rw-r--r-- 1 root root    2019 Jan 18 18:12 'Zygmunt Kaletka.txt'
# -rw-r--r-- 1 root root    2809 Jan 18 18:12 'Zygmunt Kalinowski.txt'
# -rw-r--r-- 1 root root    6640 Jan 18 18:12 'Zygmunt Kałużyński.txt'
# -rw-r--r-- 1 root root    2548 Jan 18 18:12 'Zygmunt Kamiński (biskup).txt'
# -rw-r--r-- 1 root root    5118 Jan 18 18:12 'Zygmunt Kamiński (malarz).txt'
# -rw-r--r-- 1 root root    2835 Jan 18 18:12 'Zygmunt Kapitaniak.txt'
# -rw-r--r-- 1 root root    2672 Jan 18 18:12 'Zygmunt Karaffa-Kraeuterkraft.txt'
# -rw-r--r-- 1 root root    3266 Jan 18 18:12 'Zygmunt Karasiński.txt'
# -rw-r--r-- 1 root root    2934 Jan 18 18:12 'Zygmunt Karliński.txt'
# -rw-r--r-- 1 root root    4970 Jan 18 18:12 'Zygmunt Karpiński.txt'
# -rw-r--r-- 1 root root    2635 Jan 18 18:12 'Zygmunt Karwacki.txt'
# -rw-r--r-- 1 root root    2212 Jan 18 18:12 'Zygmunt Kasperski.txt'
# -rw-r--r-- 1 root root    2301 Jan 18 18:12 'Zygmunt Katlewicz.txt'
# -rw-r--r-- 1 root root    3826 Jan 18 18:12 'Zygmunt Kawecki (inżynier).txt'
# -rw-r--r-- 1 root root    4674 Jan 18 18:12 'Zygmunt Kazimierz Piotrowski.txt'
# -rw-r--r-- 1 root root    3513 Jan 18 18:12 'Zygmunt Kęska.txt'
# -rw-r--r-- 1 root root    2016 Jan 18 18:12 'Zygmunt Kęstowicz.txt'
# -rw-r--r-- 1 root root    2656 Jan 18 18:12 'Zygmunt Kitowski.txt'
# -rw-r--r-- 1 root root    4347 Jan 18 18:12 'Zygmunt Kittel.txt'
# -rw-r--r-- 1 root root    2962 Jan 18 18:12 'Zygmunt Klemensiewicz (fizyk).txt'
# -rw-r--r-- 1 root root    4043 Jan 18 18:12 'Zygmunt Klemensiewicz (polityk).txt'
# -rw-r--r-- 1 root root    2868 Jan 18 18:12 'Zygmunt Kłosiński.txt'
# -rw-r--r-- 1 root root    5713 Jan 18 18:12 'Zygmunt Klukowski.txt'
# -rw-r--r-- 1 root root    2119 Jan 18 18:12 'Zygmunt Kolenda.txt'
# -rw-r--r-- 1 root root    3311 Jan 18 18:12 'Zygmunt Konieczny (kompozytor).txt'
# -rw-r--r-- 1 root root    3806 Jan 18 18:12 'Zygmunt Koralewski.txt'
# -rw-r--r-- 1 root root    2543 Jan 18 18:12 'Zygmunt Korybutowicz.txt'
# -rw-r--r-- 1 root root    2672 Jan 18 18:12 'Zygmunt Kostrzewski.txt'
# -rw-r--r-- 1 root root    1939 Jan 18 18:12 'Zygmunt Kotwica.txt'
# -rw-r--r-- 1 root root    2179 Jan 18 18:12 'Zygmunt Kowalczyk.txt'
# -rw-r--r-- 1 root root    2031 Jan 18 18:12 'Zygmunt Kozłowski.txt'
# -rw-r--r-- 1 root root    2958 Jan 18 18:12 'Zygmunt Koźmiński.txt'
# -rw-r--r-- 1 root root    2277 Jan 18 18:12 'Zygmunt Kozubski.txt'
# -rw-r--r-- 1 root root    2334 Jan 18 18:12 'Zygmunt Kraczkiewicz.txt'
# -rw-r--r-- 1 root root    2091 Jan 18 18:12 'Zygmunt Kramsztyk.txt'
# -rw-r--r-- 1 root root    5710 Jan 18 18:12 'Zygmunt Krasiński.txt'
# -rw-r--r-- 1 root root    4685 Jan 18 18:12 'Zygmunt Krasucki.txt'
# -rw-r--r-- 1 root root    4955 Jan 18 18:12 'Zygmunt Kratko.txt'
# -rw-r--r-- 1 root root    2924 Jan 18 18:12 'Zygmunt Kraus.txt'
# -rw-r--r-- 1 root root    4740 Jan 18 18:12 'Zygmunt Krauze.txt'
# -rw-r--r-- 1 root root    4324 Jan 18 18:12 'Zygmunt Krotkiewski.txt'
# -rw-r--r-- 1 root root    3081 Jan 18 18:12 'Zygmunt Krudowski.txt'
# -rw-r--r-- 1 root root    5714 Jan 18 18:12 'Zygmunt Kruszelnicki (prawnik).txt'
# -rw-r--r-- 1 root root    3274 Jan 18 18:12 'Zygmunt Krzysztof Jagodziński.txt'
# -rw-r--r-- 1 root root    1921 Jan 18 18:12 'Zygmunt Krzywański.txt'
# -rw-r--r-- 1 root root    2709 Jan 18 18:12 'Zygmunt Kubiak.txt'
# -rw-r--r-- 1 root root    2036 Jan 18 18:12 'Zygmunt Kubisz.txt'
# -rw-r--r-- 1 root root    2824 Jan 18 18:12 'Zygmunt Kukulski.txt'
# -rw-r--r-- 1 root root    3060 Jan 18 18:12 'Zygmunt Kuligowski.txt'
# -rw-r--r-- 1 root root    2678 Jan 18 18:12 'Zygmunt Kurnatowski-Mielżyński.txt'
# -rw-r--r-- 1 root root    2485 Jan 18 18:12 'Zygmunt Kurnatowski.txt'
# -rw-r--r-- 1 root root    2665 Jan 18 18:12 'Zygmunt Kusiak.txt'
# -rw-r--r-- 1 root root    3691 Jan 18 18:12 'Zygmunt Łakiński.txt'
# -rw-r--r-- 1 root root    2539 Jan 18 18:12 'Zygmunt Langman.txt'
# -rw-r--r-- 1 root root    2946 Jan 18 18:12 'Zygmunt Łanowski.txt'
# -rw-r--r-- 1 root root    2944 Jan 18 18:12 'Zygmunt Laskowski.txt'
# -rw-r--r-- 1 root root    2727 Jan 18 18:12 'Zygmunt Lasocki (prawnik).txt'
# -rw-r--r-- 1 root root    2660 Jan 18 18:12 'Zygmunt Ledóchowski.txt'
# -rw-r--r-- 1 root root    2089 Jan 18 18:12 'Zygmunt Łempicki (generał).txt'
# -rw-r--r-- 1 root root    2940 Jan 18 18:12 'Zygmunt Lenkiewicz.txt'
# -rw-r--r-- 1 root root    2107 Jan 18 18:12 'Zygmunt Łenyk.txt'
# -rw-r--r-- 1 root root    5707 Jan 18 18:12 'Zygmunt Lercel.txt'
# -rw-r--r-- 1 root root    3602 Jan 18 18:12 'Zygmunt Łęski.txt'
# -rw-r--r-- 1 root root    2131 Jan 18 18:12 'Zygmunt Leszczyński (1893–1940).txt'
# -rw-r--r-- 1 root root    2724 Jan 18 18:12 'Zygmunt Lewakowski.txt'
# -rw-r--r-- 1 root root    3983 Jan 18 18:12 'Zygmunt Lewoniewski.txt'
# -rw-r--r-- 1 root root    3205 Jan 18 18:12 'Zygmunt Lipiński.txt'
# -rw-r--r-- 1 root root    2319 Jan 18 18:12 'Zygmunt Lisowski.txt'
# -rw-r--r-- 1 root root    3161 Jan 18 18:12 'Zygmunt Litwińczuk.txt'
# -rw-r--r-- 1 root root    3284 Jan 18 18:12 'Zygmunt Łobaczewski-Wnuczek.txt'
# -rw-r--r-- 1 root root    2401 Jan 18 18:12 'Zygmunt Łomny.txt'
# -rw-r--r-- 1 root root    2998 Jan 18 18:12 'Zygmunt Lorec.txt'
# -rw-r--r-- 1 root root    5572 Jan 18 18:12 'Zygmunt Lorentz.txt'
# -rw-r--r-- 1 root root    2352 Jan 18 18:12 'Zygmunt Łotocki.txt'
# -rw-r--r-- 1 root root    2809 Jan 18 18:12 'Zygmunt Łoziński.txt'
# -rw-r--r-- 1 root root    2487 Jan 18 18:12 'Zygmunt Lubertowicz.txt'
# -rw-r--r-- 1 root root    2184 Jan 18 18:12 'Zygmunt Lubicz-Zaleski.txt'
# -rw-r--r-- 1 root root    4115 Jan 18 18:12 'Zygmunt Ludwik Tomaszewski.txt'
# -rw-r--r-- 1 root root    7742 Jan 18 18:12 'Zygmunt Luksemburski.txt'
# -rw-r--r-- 1 root root    1940 Jan 18 18:12 'Zygmunt Łupina.txt'
# -rw-r--r-- 1 root root    2185 Jan 18 18:12 'Zygmunt Machoy.txt'
# -rw-r--r-- 1 root root    1963 Jan 18 18:12 'Zygmunt Mackiewicz (polityk).txt'
# -rw-r--r-- 1 root root    2040 Jan 18 18:12 'Zygmunt Majerski.txt'
# -rw-r--r-- 1 root root    2931 Jan 18 18:12 'Zygmunt Malanowicz.txt'
# -rw-r--r-- 1 root root    6823 Jan 18 18:12 'Zygmunt Malewski.txt'
# -rw-r--r-- 1 root root    5218 Jan 18 18:12 'Zygmunt Marek.txt'
# -rw-r--r-- 1 root root    2128 Jan 18 18:12 'Zygmunt Marjenstrass.txt'
# -rw-r--r-- 1 root root    2266 Jan 18 18:12 'Zygmunt Markiewicz.txt'
# -rw-r--r-- 1 root root    3188 Jan 18 18:12 'Zygmunt Markowski.txt'
# -rw-r--r-- 1 root root    4302 Jan 18 18:12 'Zygmunt Marszewski.txt'
# -rw-r--r-- 1 root root    2072 Jan 18 18:12 'Zygmunt Maszczyk.txt'
# -rw-r--r-- 1 root root    2187 Jan 18 18:12 'Zygmunt Mazur.txt'
# -rw-r--r-- 1 root root    1942 Jan 18 18:12 'Zygmunt Merzbach.txt'
# -rw-r--r-- 1 root root    2548 Jan 18 18:12 'Zygmunt Męski.txt'
# -rw-r--r-- 1 root root    3141 Jan 18 18:12 'Zygmunt Michałowski (dziennikarz).txt'
# -rw-r--r-- 1 root root    3655 Jan 18 18:12 'Zygmunt Michelis.txt'
# -rw-r--r-- 1 root root    4782 Jan 18 18:12 'Zygmunt Mierczyk.txt'
# -rw-r--r-- 1 root root    2599 Jan 18 18:12 'Zygmunt Milewicz.txt'
# -rw-r--r-- 1 root root    4504 Jan 18 18:12 'Zygmunt Miłkowski (oficer WP).txt'
# -rw-r--r-- 1 root root    4360 Jan 18 18:12 'Zygmunt Miłkowski (pisarz).txt'
# -rw-r--r-- 1 root root    2460 Jan 18 18:12 'Zygmunt Milli.txt'
# -rw-r--r-- 1 root root    2944 Jan 18 18:12 'Zygmunt Miłoszewski.txt'
# -rw-r--r-- 1 root root    7060 Jan 18 18:12 'Zygmunt Mineyko.txt'
# -rw-r--r-- 1 root root    4997 Jan 18 18:12 'Zygmunt Mitera.txt'
# -rw-r--r-- 1 root root    4699 Jan 18 18:12 'Zygmunt Młot-Przepałkowski.txt'
# -rw-r--r-- 1 root root   12257 Jan 18 18:12 'Zygmunt Mocarski.txt'
# -rw-r--r-- 1 root root    4848 Jan 18 18:12 'Zygmunt Moczyński.txt'
# -rw-r--r-- 1 root root    4726 Jan 18 18:12 'Zygmunt Modzelewski.txt'
# -rw-r--r-- 1 root root    2594 Jan 18 18:12 'Zygmunt Mogiła-Lisowski.txt'
# -rw-r--r-- 1 root root    8958 Jan 18 18:12 'Zygmunt Mokrzecki.txt'
# -rw-r--r-- 1 root root    4397 Jan 18 18:12 'Zygmunt Molik.txt'
# -rw-r--r-- 1 root root    3243 Jan 18 18:12 'Zygmunt Morozewicz.txt'
# -rw-r--r-- 1 root root    2175 Jan 18 18:12 'Zygmunt Moskwa.txt'
# -rw-r--r-- 1 root root    2038 Jan 18 18:12 'Zygmunt Moszczeński.txt'
# -rw-r--r-- 1 root root    4241 Jan 18 18:12 'Zygmunt Mycielski.txt'
# -rw-r--r-- 1 root root    2730 Jan 18 18:12 'Zygmunt Mysłakowski.txt'
# -rw-r--r-- 1 root root    6399 Jan 18 18:12 'Zygmunt Nagórski (1884–1973).txt'
# -rw-r--r-- 1 root root    3423 Jan 18 18:12 'Zygmunt Nagórski (1912–2011).txt'
# -rw-r--r-- 1 root root    2047 Jan 18 18:12 'Zygmunt Najdowski.txt'
# -rw-r--r-- 1 root root    2345 Jan 18 18:12 'Zygmunt Nawratil (pułkownik).txt'
# -rw-r--r-- 1 root root    2203 Jan 18 18:12 'Zygmunt Nawratil (sędzia).txt'
# -rw-r--r-- 1 root root    3603 Jan 18 18:12 'Zygmunt Netzer.txt'
# -rw-r--r-- 1 root root    1938 Jan 18 18:12 'Zygmunt Nieciecki.txt'
# -rw-r--r-- 1 root root   10538 Jan 18 18:12 'Zygmunt Noskowski.txt'
# -rw-r--r-- 1 root root    2156 Jan 18 18:12 'Zygmunt Nowakowski (artysta).txt'
# -rw-r--r-- 1 root root    3043 Jan 18 18:12 'Zygmunt Nowakowski (działacz).txt'
# -rw-r--r-- 1 root root    2603 Jan 18 18:12 'Zygmunt Nowicki (aktor).txt'
# -rw-r--r-- 1 root root    2315 Jan 18 18:12 'Zygmunt Ochmański.txt'
# -rw-r--r-- 1 root root    2521 Jan 18 18:12 'Zygmunt Odrowąż-Zawadzki.txt'
# -rw-r--r-- 1 root root    3234 Jan 18 18:12 'Zygmunt Okołów.txt'
# -rw-r--r-- 1 root root    4801 Jan 18 18:12 'Zygmunt (opera).txt'
# -rw-r--r-- 1 root root    2332 Jan 18 18:12 'Zygmunt Oskierko.txt'
# -rw-r--r-- 1 root root    6386 Jan 18 18:12 'Zygmunt Pacuszka.txt'
# -rw-r--r-- 1 root root    2808 Jan 18 18:12 'Zygmunt Palczowski (zm. 1587).txt'
# -rw-r--r-- 1 root root    2598 Jan 18 18:12 'Zygmunt Patryn.txt'
# -rw-r--r-- 1 root root    3188 Jan 18 18:12 'Zygmunt Pawlaczyk.txt'
# -rw-r--r-- 1 root root    4067 Jan 18 18:12 'Zygmunt Pawłowicz.txt'
# -rw-r--r-- 1 root root    4883 Jan 18 18:12 'Zygmunt Pawlus.txt'
# -rw-r--r-- 1 root root    3493 Jan 18 18:12 'Zygmunt Peszkowski (cukiernik).txt'
# -rw-r--r-- 1 root root    2529 Jan 18 18:12 'Zygmunt Piasecki.txt'
# -rw-r--r-- 1 root root    4749 Jan 18 18:12 'Zygmunt Piękniewski.txt'
# -rw-r--r-- 1 root root    2372 Jan 18 18:12 'Zygmunt Pietkiewicz.txt'
# -rw-r--r-- 1 root root    3072 Jan 18 18:12 'Zygmunt Pietruszczyński.txt'
# -rw-r--r-- 1 root root    2970 Jan 18 18:12 'Zygmunt Piotrowski.txt'
# -rw-r--r-- 1 root root    3766 Jan 18 18:12 'Zygmunt Pistl.txt'
# -rw-r--r-- 1 root root    4099 Jan 18 18:12 'Zygmunt Piwnicki.txt'
# -rw-r--r-- 1 root root    5017 Jan 18 18:12 'Zygmunt Platonoff-Plater.txt'
# -rw-r--r-- 1 root root    2471 Jan 18 18:12 'Zygmunt Platowski.txt'
# -rw-r--r-- 1 root root    2315 Jan 18 18:12 'Zygmunt Pluciński.txt'
# -rw-r--r-- 1 root root    7021 Jan 18 18:12 'Zygmunt Podhorski.txt'
# -rw-r--r-- 1 root root    2919 Jan 18 18:12 'Zygmunt Polakowski.txt'
# -rw-r--r-- 1 root root    3838 Jan 18 18:12 'Zygmunt Policiewicz.txt'
# -rw-r--r-- 1 root root    2058 Jan 18 18:12 'Zygmunt Pomarański.txt'
# -rw-r--r-- 1 root root    3773 Jan 18 18:12 'Zygmunt Poniatowski (duchowny).txt'
# -rw-r--r-- 1 root root    3399 Jan 18 18:12 'Zygmunt Powała-Dzieślewski.txt'
# -rw-r--r-- 1 root root    2976 Jan 18 18:12 'Zygmunt Psarski.txt'
# -rw-r--r-- 1 root root    4631 Jan 18 18:12 'Zygmunt Puchalik.txt'
# -rw-r--r-- 1 root root    7412 Jan 18 18:12 'Zygmunt Pukianiec.txt'
# -rw-r--r-- 1 root root    5023 Jan 18 18:12 'Zygmunt Puławski.txt'
# -rw-r--r-- 1 root root    1970 Jan 18 18:12 'Zygmunt Rabski.txt'
# -rw-r--r-- 1 root root    1944 Jan 18 18:12 'Zygmunt Radliński.txt'
# -rw-r--r-- 1 root root    4095 Jan 18 18:12 'Zygmunt Radnicki.txt'
# -rw-r--r-- 1 root root    2304 Jan 18 18:12 'Zygmunt Radzimiński.txt'
# -rw-r--r-- 1 root root    3068 Jan 18 18:12 'Zygmunt Rajski.txt'
# -rw-r--r-- 1 root root    2116 Jan 18 18:12 'Zygmunt Reingold.txt'
# -rw-r--r-- 1 root root    2800 Jan 18 18:12 'Zygmunt Reliszko.txt'
# -rw-r--r-- 1 root root    3163 Jan 18 18:12 'Zygmunt Rodakowski.txt'
# -rw-r--r-- 1 root root    2774 Jan 18 18:12 'Zygmunt Roguski.txt'
# -rw-r--r-- 1 root root    2619 Jan 18 18:12 'Zygmunt Rolat.txt'
# -rw-r--r-- 1 root root    2805 Jan 18 18:12 'Zygmunt Rozwadowski.txt'
# -rw-r--r-- 1 root root    2345 Jan 18 18:12 'Zygmunt Rucker (1897–1964).txt'
# -rw-r--r-- 1 root root    4620 Jan 18 18:12 'Zygmunt Rudolf.txt'
# -rw-r--r-- 1 root root    2844 Jan 18 18:12 'Zygmunt Rudomino.txt'
# -rw-r--r-- 1 root root    6580 Jan 18 18:12 'Zygmunt Rumel.txt'
# -rw-r--r-- 1 root root    2537 Jan 18 18:12 'Zygmunt Rusinek.txt'
# -rw-r--r-- 1 root root    2915 Jan 18 18:12 'Zygmunt Ruszczyc.txt'
# -rw-r--r-- 1 root root    2843 Jan 18 18:12 'Zygmunt Rybicki.txt'
# -rw-r--r-- 1 root root    1917 Jan 18 18:12 'Zygmunt Rychert.txt'
# -rw-r--r-- 1 root root    3561 Jan 18 18:12 'Zygmunt Rydlewski.txt'
# -rw-r--r-- 1 root root    5704 Jan 18 18:12 'Zygmunt Rylski.txt'
# -rw-r--r-- 1 root root    2333 Jan 18 18:12 'Zygmunt Rymkiewicz.txt'
# -rw-r--r-- 1 root root    9411 Jan 18 18:12 'Zygmunt Rytel.txt'
# -rw-r--r-- 1 root root    4078 Jan 18 18:12 'Zygmunt Sajna.txt'
# -rw-r--r-- 1 root root    2319 Jan 18 18:12 'Zygmunt Saloni.txt'
# -rw-r--r-- 1 root root    4804 Jan 18 18:12 'Zygmunt Sarna.txt'
# -rw-r--r-- 1 root root    3376 Jan 18 18:12 'Zygmunt Sarnecki.txt'
# -rw-r--r-- 1 root root    3821 Jan 18 18:12 'Zygmunt Sawicki (1910–1995).txt'
# -rw-r--r-- 1 root root    2128 Jan 18 18:12 'Zygmunt Schreter.txt'
# -rw-r--r-- 1 root root    4879 Jan 18 18:12 'Zygmunt Siedlecki (lekarz).txt'
# -rw-r--r-- 1 root root    6329 Jan 18 18:12 'Zygmunt Sierakowski.txt'
# -rw-r--r-- 1 root root    2230 Jan 18 18:12 'Zygmunt Sioda.txt'
# -rw-r--r-- 1 root root    2710 Jan 18 18:12 'Zygmunt Skibniewski.txt'
# -rw-r--r-- 1 root root    2765 Jan 18 18:12 'Zygmunt Skoczek.txt'
# -rw-r--r-- 1 root root    4049 Jan 18 18:12 'Zygmunt Skórzewski.txt'
# -rw-r--r-- 1 root root    2864 Jan 18 18:12 'Zygmunt Skórzyński.txt'
# -rw-r--r-- 1 root root    4684 Jan 18 18:12 'Zygmunt Słomiński.txt'
# -rw-r--r-- 1 root root    1989 Jan 18 18:12 'Zygmunt Sobień.txt'
# -rw-r--r-- 1 root root    3168 Jan 18 18:12 'Zygmunt Sokołowski (1908–1953).txt'
# -rw-r--r-- 1 root root    3353 Jan 18 18:12 'Zygmunt Solorz-Żak.txt'
# -rw-r--r-- 1 root root    2153 Jan 18 18:12 'Zygmunt Sowa-Sowiński.txt'
# -rw-r--r-- 1 root root    5899 Jan 18 18:12 'Zygmunt Sowiński.txt'
# -rw-r--r-- 1 root root    2753 Jan 18 18:12 'Zygmunt Stanisław Czarnecki.txt'
# -rw-r--r-- 1 root root    2004 Jan 18 18:12 'Zygmunt Stanisław Makowski.txt'
# -rw-r--r-- 1 root root    3366 Jan 18 18:12 'Zygmunt Steuermann.txt'
# -rw-r--r-- 1 root root    2600 Jan 18 18:12 'Zygmunt Stojowski.txt'
# -rw-r--r-- 1 root root    3921 Jan 18 18:12 'Zygmunt Straszewicz.txt'
# -rw-r--r-- 1 root root    2475 Jan 18 18:12 'Zygmunt Sułowski.txt'
# -rw-r--r-- 1 root root    2204 Jan 18 18:12 'Zygmunt Surowiec.txt'
# -rw-r--r-- 1 root root    5318 Jan 18 18:12 'Zygmunt Świechowski.txt'
# -rw-r--r-- 1 root root    4867 Jan 18 18:12 'Zygmunt Syrokomski.txt'
# -rw-r--r-- 1 root root    2431 Jan 18 18:12 'Zygmunt Szacherski.txt'
# -rw-r--r-- 1 root root    3774 Jan 18 18:12 'Zygmunt Szadkowski.txt'
# -rw-r--r-- 1 root root    3711 Jan 18 18:12 'Zygmunt Szafranowski.txt'
# -rw-r--r-- 1 root root    1946 Jan 18 18:12 'Zygmunt Szantroch.txt'
# -rw-r--r-- 1 root root    4278 Jan 18 18:12 'Zygmunt Szatkowski.txt'
# -rw-r--r-- 1 root root    2990 Jan 18 18:12 'Zygmunt Szczepański.txt'
# -rw-r--r-- 1 root root   21449 Jan 18 18:12 'Zygmunt Szczęsny Feliński.txt'
# -rw-r--r-- 1 root root    4390 Jan 18 18:12 'Zygmunt Szczotkowski.txt'
# -rw-r--r-- 1 root root    2424 Jan 18 18:12 'Zygmunt Szempliński.txt'
# -rw-r--r-- 1 root root   21060 Jan 18 18:12 'Zygmunt Szendzielarz.txt'
# -rw-r--r-- 1 root root    2617 Jan 18 18:12 'Zygmunt Szkocny.txt'
# -rw-r--r-- 1 root root    2638 Jan 18 18:12 'Zygmunt Szpingier.txt'
# -rw-r--r-- 1 root root    2893 Jan 18 18:12 'Zygmunt Szułdrzyński.txt'
# -rw-r--r-- 1 root root    4901 Jan 18 18:12 'Zygmunt Szymanowski (bakteriolog).txt'
# -rw-r--r-- 1 root root    3167 Jan 18 18:12 'Zygmunt Szymanowski.txt'
# -rw-r--r-- 1 root root    4513 Jan 18 18:12 'Zygmunt Szypold.txt'
# -rw-r--r-- 1 root root    2570 Jan 18 18:12 'Zygmunt Tadeusz Turno.txt'
# -rw-r--r-- 1 root root    4511 Jan 18 18:12 'Zygmunt Terakowski.txt'
# -rw-r--r-- 1 root root    2560 Jan 18 18:12 'Zygmunt Trószyński.txt'
# -rw-r--r-- 1 root root    2381 Jan 18 18:12 'Zygmunt Trylański.txt'
# -rw-r--r-- 1 root root    1949 Jan 18 18:12 'Zygmunt Turkiewicz.txt'
# -rw-r--r-- 1 root root    2777 Jan 18 18:12 'Zygmunt Turkow.txt'
# -rw-r--r-- 1 root root    2989 Jan 18 18:12 'Zygmunt Turski.txt'
# -rw-r--r-- 1 root root    4544 Jan 18 18:12 'Zygmunt Ułanowicz.txt'
# -rw-r--r-- 1 root root    4083 Jan 18 18:12 'Zygmunt Ulm.txt'
# -rw-r--r-- 1 root root    2967 Jan 18 18:12 'Zygmunt Unrug.txt'
# -rw-r--r-- 1 root root    3862 Jan 18 18:12 'Zygmunt Urbanyj.txt'
# -rw-r--r-- 1 root root    4101 Jan 18 18:12 'Zygmunt Vetulani (dyplomata).txt'
# -rw-r--r-- 1 root root    5594 Jan 18 18:12 'Zygmunt Vetulani (informatyk).txt'
# -rw-r--r-- 1 root root    3616 Jan 18 18:12 'Zygmunt Vogel.txt'
# -rw-r--r-- 1 root root    2835 Jan 18 18:12 'Zygmunt Walkowski.txt'
# -rw-r--r-- 1 root root    2193 Jan 18 18:12 'Zygmunt Walter-Janke.txt'
# -rw-r--r-- 1 root root    2187 Jan 18 18:12 'Zygmunt Warczygłowa.txt'
# -rw-r--r-- 1 root root    7194 Jan 18 18:12 'Zygmunt Waśniewski.txt'
# -rw-r--r-- 1 root root    5910 Jan 18 18:12 'Zygmunt Wasserab.txt'
# -rw-r--r-- 1 root root    3244 Jan 18 18:12 'Zygmunt Weiss.txt'
# -rw-r--r-- 1 root root    2332 Jan 18 18:12 'Zygmunt Wenda.txt'
# -rw-r--r-- 1 root root    9487 Jan 18 18:12 'Zygmunt Wichary.txt'
# -rw-r--r-- 1 root root    2394 Jan 18 18:12 'Zygmunt Wielopolski (1863–1919).txt'
# -rw-r--r-- 1 root root    2308 Jan 18 18:12 'Zygmunt Wierzbowski (1904–2002).txt'
# -rw-r--r-- 1 root root    6892 Jan 18 18:12 'Zygmunt Wilczyński.txt'
# -rw-r--r-- 1 root root    3484 Jan 18 18:12 'Zygmunt Witymir Bieńkowski.txt'
# -rw-r--r-- 1 root root    4798 Jan 18 18:12 'Zygmunt Wojnicz-Sianożęcki.txt'
# -rw-r--r-- 1 root root    2008 Jan 18 18:12 'Zygmunt Wolanin.txt'
# -rw-r--r-- 1 root root    2703 Jan 18 18:12 'Zygmunt Wolski (1908-1942).txt'
# -rw-r--r-- 1 root root    2812 Jan 18 18:12 'Zygmunt Wóycicki.txt'
# -rw-r--r-- 1 root root    2532 Jan 18 18:12 'Zygmunt Wróblewski.txt'
# -rw-r--r-- 1 root root    2582 Jan 18 18:12 'Zygmunt Wrzodak.txt'
# -rw-r--r-- 1 root root    3311 Jan 18 18:12 'Zygmunt Wyrobek.txt'
# -rw-r--r-- 1 root root    2152 Jan 18 18:12 'Zygmunt Zagórowski.txt'
# -rw-r--r-- 1 root root    1998 Jan 18 18:12 'Zygmunt Zagórski.txt'
# -rw-r--r-- 1 root root    7973 Jan 18 18:12 'Zygmunt Zahorski.txt'
# -rw-r--r-- 1 root root    2695 Jan 18 18:12 'Zygmunt Zakrzewski.txt'
# -rw-r--r-- 1 root root    4425 Jan 18 18:12 'Zygmunt Zalewski.txt'
# -rw-r--r-- 1 root root   15242 Jan 18 18:12 'Zygmunt Zaremba.txt'
# -rw-r--r-- 1 root root    2494 Jan 18 18:12 'Zygmunt Zawadowski.txt'
# -rw-r--r-- 1 root root    3280 Jan 18 18:12 'Zygmunt Zieliński (ekonomista).txt'
# -rw-r--r-- 1 root root    3640 Jan 18 18:12 'Zygmunt Zieliński (generał broni).txt'
# -rw-r--r-- 1 root root    2284 Jan 18 18:12 'Zygmunt Zieliński (generał dywizji).txt'
# -rw-r--r-- 1 root root    2739 Jan 18 18:12 'Zygmunt Zieliński (historyk).txt'
# -rw-r--r-- 1 root root    2419 Jan 18 18:12 'Zygmunt Zieliński (samorządowiec).txt'
# -rw-r--r-- 1 root root    2813 Jan 18 18:12 'Zygmunt Ziembiński.txt'
# -rw-r--r-- 1 root root    6639 Jan 18 18:12 'Zygmunt Zimowski.txt'
# -rw-r--r-- 1 root root    2153 Jan 18 18:12 'Zygmunt Zintel.txt'
# -rw-r--r-- 1 root root    2759 Jan 18 18:12 'Zygmunt Żuławski.txt'
# -rw-r--r-- 1 root root    3316 Jan 18 18:12 'Zygmunt Zygmuntowicz.txt'
# -rw-r--r-- 1 root root   12120 Jan 18 18:12 'Zygmunt Żyłka-Żebracki.txt'
# -rw-r--r-- 1 root root    3090 Jan 18 18:12 'Zygmunt Żytomirski.txt'
# -rw-r--r-- 1 root root    5561 Jan 18 18:12 'Zygoballus sexpunctatus.txt'
# -rw-r--r-- 1 root root    2260 Jan 18 18:12  Zygodowice.txt
# -rw-r--r-- 1 root root    1929 Jan 18 18:12  Zygospora.txt
# -rw-r--r-- 1 root root    1933 Jan 18 18:12 'Zygry (wieś).txt'
# -rw-r--r-- 1 root root    3202 Jan 18 18:12 'Zygzakowiec kokornakowiec.txt'
# -rw-r--r-- 1 root root    4598 Jan 18 18:12  Zyndranowa.txt
# -rw-r--r-- 1 root root    3230 Jan 18 18:12  Zyprazydon.txt
# -rw-r--r-- 1 root root    1904 Jan 18 18:12 'Zysk i S-ka.txt'
# -rw-r--r-- 1 root root    3930 Jan 18 18:12 'Zysk rezydualny.txt'
# -rw-r--r-- 1 root root    8396 Jan 18 18:12 'Zyta Burbon-Parmeńska.txt'
# -rw-r--r-- 1 root root    3515 Jan 18 18:12 'Zyta Gilowska.txt'
# -rw-r--r-- 1 root root    2520 Jan 18 18:12 'Zyta z Lukki.txt'
# -rw-r--r-- 1 root root   11933 Jan 18 18:12  Zytglogge.txt
# -rw-r--r-- 1 root root    1957 Jan 18 18:12  Zyzkowate.txt

# %% [markdown]
# Backup your plwiki to your local folder to avoid downloading, unzipping and extracting. (split_wiki is quite fast so it can be done again)

# %%
# !cp /root/.fastai/data/plwiki/plwiki /content/gdrive/My\ Drive/

# %%
#!head -20 /content/gdrive/My\ Drive/language_model/data/plwiki/plwiki_old

# %%
''' I rewrited plwiki with changing coding under another enviroment, but I think it is not needed here
name3 = 'newplwiki'
with open(path/name,'r',encoding='utf-8') as file:
    with open(path/name3,'w',encoding='utf-8') as file2:
        for line in file:
            #line = file.readline()
            try:
                line2 = line.encode('cp1250').decode('utf-8')
                file2.write(line2)
            except:
                words = line2.split(' ')
                for w in words:
                    file2.write(w+' ')
'''

# %% [markdown]
# Creating test environmet with small dataset.

# %%
mkdir /root/.fastai/data/plwiki/doc_s

# %%
# !cp /root/.fastai/data/plwiki/docs/Zy* /root/.fastai/data/plwiki/doc_s/

# %% [markdown]
# Choose if you would like to work on full data or a sample.

# %%
dest = '/root/.fastai/data/plwiki/doc_s'

# %%
dest = '/root/.fastai/data/plwiki/docs'

# %%
# !ls -l /root/.fastai/data/plwiki/doc_s/tmp
# Out:
# total 0

# %% [markdown]
# # Model creation

# %%
# !pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.6/dist-packages (0.1.85)

# %% [markdown]
# After first run you will get an error:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/root/.fastai/data/plwiki/doc_s/tmp/spm/spm.vocab'
#
# Please click on error link /usr/local/lib/python3.6/dist-packages/fastai/text/data.py and do some changes:
# In ```def train_sentencepiece``` change from code
# ```
#     cache_dir = cache_dir/'spm'
#     SentencePieceTrainer.Train(" ".join([
#         f"--input={raw_text_path} --max_sentence_length={max_sentence_len}",
#         f"--character_coverage={ifnone(char_coverage, 0.99999 if lang in full_char_coverage_langs else 0.9998)}",
#         f"--unk_id={len(defaults.text_spec_tok)} --pad_id=-1 --bos_id=-1 --eos_id=-1",
#         f"--user_defined_symbols={','.join(spec_tokens)}",
#         f'--model_prefix="cache_dir" --vocab_size={vocab_sz} --model_type={model_type}']))
#     raw_text_path.unlink()
#     return cache_dir
# ```
# to:
# ```
#     return_cache_dir = cache_dir
#     cache_dir = cache_dir/'spm'
#     SentencePieceTrainer.Train(" ".join([
#         f"--input={raw_text_path} --max_sentence_length={max_sentence_len}",
#         f"--character_coverage={ifnone(char_coverage, 0.99999 if lang in full_char_coverage_langs else 0.9998)}",
#         f"--unk_id={len(defaults.text_spec_tok)} --pad_id=-1 --bos_id=-1 --eos_id=-1",
#         f"--user_defined_symbols={','.join(spec_tokens)}",
#         f'--model_prefix={cache_dir} --vocab_size={vocab_sz} --model_type={model_type}']))
#     raw_text_path.unlink()
#     return return_cache_dir
# ```
#
# and in ```def process(self, ds):```
# change line which starts with:
# ```
# if self.n_cpus <= 1:
# ```
# to
# ```
# if self.n_cpus <= 4:
# ```
#
# there restart Runtime, do not execute autoreload section, remmeber to backup plwiki file and restore it

# %%
# !rm -r /root/.fastai/data/plwiki/doc_s/tmp
bs=128
data = (TextList.from_folder(dest, processor=[OpenFileProcessor(), SPProcessor(lang='pl')])
        .split_by_rand_pct(0.1, seed=42)
        .label_for_lm(ignore_empty=True)
        .databunch(bs=bs))

#print(data)
#data.save('pl_databunch')
len(data.vocab.itos),len(data.train_ds)
# Out:
# (11328, 399)

# %%
data.save('pl_databunch')

# %%
# !cp /root/.fastai/data/plwiki/docs/pl_databunch /content/gdrive/My\ Drive/language_model/data/plwiki/

# %%
data.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>idx</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>▁1906 –19 13 ▁uczył ▁się ▁w ▁gimnazjum ▁w ▁xxmaj ▁orle , ▁ a ▁po ▁uzyskani u ▁świadectw a ▁dojrzałości ▁rozpoczął ▁studia ▁na ▁xxmaj ▁wydziale ▁xxmaj ▁medycznym ▁xxmaj ▁uniwersytetu ▁w ▁xxmaj ▁moskwie . ▁w ▁luty m ▁1915 ▁roku ▁powołany ▁do ▁armii ▁rosyjskiej , ▁gdzie ▁ukończył ▁xxmaj ▁aleksandr owską ▁xxmaj ▁szkołę ▁xxmaj ▁piechoty ▁w ▁xxmaj ▁moskwie . ▁xxmaj ▁następnie , ▁kolejno ▁był ▁dowódcą ▁kompanii ▁w ▁ 33 ▁pułku ▁piechoty , ▁oddziału ▁łączności</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>▁xxmaj ▁paryskiej ▁oraz ▁xxmaj ▁ biuletyn u ▁xxmaj ▁dolnośląski ego ▁wydawan ego ▁przez ▁xxmaj ▁kornel a ▁xxmaj ▁morawiecki ego . ▁xxmaj ▁jako ▁członek ▁ solidarności ▁wraz ▁z ▁grupą ▁osób ▁xxmaj ▁ krzysztof ▁xxmaj ▁tenerowicz , ▁xxmaj ▁piotr ▁xxmaj ▁załuski , ▁xxmaj ▁ jarosław ▁xxmaj ▁ szym kiewicz , ▁xxmaj ▁jacenty ▁xxmaj ▁lipiński . ▁w ▁stanie ▁wojennym ▁już ▁od ▁13 ▁grudnia ▁1981 ▁roku ▁brał ▁udział ▁w ▁zorganizowan ej ▁przez ▁xxmaj ▁tadeusza</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>▁( zm . ▁w ▁1939 ), ▁małżeństwo ▁było ▁bezdzietne . ▁&lt; ▁/ ▁doc &gt; ▁xxbos ▁xxmaj ▁zygmunt ▁xxmaj ▁pomarański ▁xxmaj ▁zygmunt ▁xxmaj ▁pomarański ▁ps . ▁" br z ó zka " ▁( ur . ▁20 ▁stycznia ▁1898 ▁w ▁xxmaj ▁warszawie , ▁zm . ▁29 ▁września ▁1941 ▁w ▁xxmaj ▁auschwitz ) ▁– ▁polski ▁żołnierz ▁xxmaj ▁pierwszej ▁xxmaj ▁kompanii ▁xxmaj ▁kadrowej , ▁kapitan ▁rezerwy ▁xxmaj ▁wojska ▁xxmaj ▁polskiego , ▁komendant ▁xxmaj ▁polskiej</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>o - wiedeńskiej ▁xxmaj ▁kolei ▁xxmaj ▁żelaznej . ▁w ▁1908 ▁wstąpił ▁do ▁warszawskiego ▁seminarium ▁duchownego , ▁w ▁1913 ▁przy jął ▁święcenia ▁ su b dia kon atu ▁i ▁został ▁skierowany ▁na ▁studia ▁do ▁xxmaj ▁gr ego rian um , ▁gdzie ▁obroni ł ▁pracę ▁doktorsk ą ▁z ▁prawa ▁kanonicznego . ▁xxmaj ▁święcenia ▁kapłańskie ▁przy jął ▁30 ▁listopada ▁1916 . ▁xxmaj ▁po ▁święcenia ch ▁pracował ▁krótko ▁jako ▁wikariusz ▁w ▁parafii ▁św .</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>▁– ▁zgrupowanie , ▁wyjazd ▁na ▁mecz e ▁z ▁xxmaj ▁jugosławi ą ▁przed ▁olimpiad ą ▁w ▁xxmaj ▁montrealu . ▁xxmaj ▁zygmunt ▁xxmaj ▁pacuszka ▁wraz ▁z ▁xxmaj ▁kazimierzem ▁xxmaj ▁ szczerb ą ▁zostali ▁wytypowan i ▁w ▁ wadze ▁ lekkopółśredniej ▁do ▁udziału ▁w ▁olimpiad zie , ▁która ▁od bę dzie ▁się ▁w ▁xxmaj ▁montrealu ▁jesienią . ▁xxmaj ▁do ▁xxmaj ▁belgrad u ▁10 ▁kadr owicz ów ▁udał o ▁się ▁pod ▁ wodzą ▁trenera</td>
#     </tr>
#   </tbody>
# </table>

# %%
# !ls -lh /root/.fastai/data/plwiki/docs/pl*
# Out:
# -rw-r--r-- 1 root root 1.9G Jan 11 20:01 /root/.fastai/data/plwiki/docs/pl_databunch

# %%
fastai_local_files = '/content/gdrive/My Drive/language_model/data/plwiki/'

# %%
bs = 128
data = load_data(dest,'pl_databunch',bs=bs)

# %%
epochs_data = '/content/gdrive/My Drive/language_model/data/plwiki/epochs_data2/model'

# %%
from fastai.callbacks import SaveModelCallback

# %%
learn = language_model_learner(data, AWD_LSTM, drop_mult=0.1, wd=0.1, pretrained=False).to_fp16()

# %%
lr = 3e-3
lr *= bs/48  # Scale learning rate by batch size

# %%
learn.unfreeze()
#learn.fit_one_cycle(10, lr, moms=(0.8,0.7))
learn.fit_one_cycle(10, lr, moms=(0.8,0.7), 
       callbacks=[SaveModelCallback(learn, every='epoch',  
                  monitor='accuracy', name=epochs_data)])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>7.169099</td>
#       <td>6.631194</td>
#       <td>0.119754</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.608907</td>
#       <td>5.999218</td>
#       <td>0.143731</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.925918</td>
#       <td>5.189696</td>
#       <td>0.202660</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.276292</td>
#       <td>4.722189</td>
#       <td>0.238504</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.760765</td>
#       <td>4.503273</td>
#       <td>0.258984</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.345967</td>
#       <td>4.362858</td>
#       <td>0.272749</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.981343</td>
#       <td>4.300931</td>
#       <td>0.281827</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.595247</td>
#       <td>4.301994</td>
#       <td>0.285324</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.205735</td>
#       <td>4.354615</td>
#       <td>0.282366</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.907485</td>
#       <td>4.382166</td>
#       <td>0.280748</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(10, lr, moms=(0.8,0.7), 
                    start_epoch=8,
                    callbacks=[SaveModelCallback(learn, 
                    every='epoch', monitor='accuracy', 
                    name=epochs_data)])
# Out:
# Loaded /content/gdrive/My Drive/language_model/data/plwiki/epochs_data/model_7
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>8</td>
#       <td>3.614749</td>
#       <td>3.653196</td>
#       <td>0.364300</td>
#       <td>1:58:49</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.516606</td>
#       <td>3.531486</td>
#       <td>0.380321</td>
#       <td>1:58:48</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.to_fp32().save(lm_fns[0], with_opt=False)
learn.data.vocab.save(lm_fns[1].with_suffix('.pkl'))

# %%
# !ls -l /root/.fastai/data/plwiki/*
# Out:
# -rw-r--r-- 1 root root 129095776 Jan 13 20:49 /root/.fastai/data/plwiki/plfine_tuned_enc.pth
#
# /root/.fastai/data/plwiki/models:
# total 126756
# -rw-r--r-- 1 root root 129216143 Jan 13 20:40 pl_wt.pth
# -rw-r--r-- 1 root root    578894 Jan 13 20:40 pl_wt_vocab.pkl

# %%
# !cp /root/.fastai/data/plwiki/*.pth /content/gdrive/My\ Drive/language_model/data/plwiki/models/

# %%
learn.save_encoder(f'/root/.fastai/data/plwiki/{lang}fine_tuned_enc')

# %%
#quality check - does the model predict sensible tokens?
TEXT = "to był jeden"
N_WORDS = 40
N_SENTENCES = 2

# %%
# !mkdir /root/.fastai/data/plwiki/docs/tmp

# %%
# !cp /content/gdrive/My\ Drive/language_model/data/plwiki/spm.* /root/.fastai/data/plwiki/docs/tmp

# %%
print("\n".join(learn.predict(TEXT, N_WORDS, temperature=0.92) for _ in range(N_SENTENCES)))
# Out:
# to był jeden ▁z ▁najwybitniejszy ch ▁członków ▁xxmaj ▁hieronim a ▁xxmaj ▁bo p su , ▁jednak ▁większość ▁co ▁towarzyszył a ▁mu ▁zwycięstwo , ▁jak ▁i ▁rezydent ▁w ▁xxmaj ▁zaklikow ie . ▁xxmaj ▁ le pas ty k ▁zdobył ▁8 ▁stycznia ▁1981 ▁xxmaj ▁peter
# to był jeden ▁z ▁czołowy ch ▁chłopów , ▁martwe ▁naukowe , ▁pasj i ▁i ▁obrońcy . ▁xxmaj ▁na konywał ▁stanowisko ▁zastępcy ▁docenta ▁podobny m ▁w ▁charakterze ▁starszego ▁dyrektora . ▁1 ▁maja ▁1962 , ▁po ▁ o puszczeni u ▁xxup ▁ps p ▁„ piast
